# %% [markdown]
# ## Cleaning and preprocessing of raw data

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from nltk.stem import WordNetLemmatizer
import nltk
from sklearn.preprocessing import MinMaxScaler
import string
from nltk.corpus import stopwords
from tensorflow.keras.regularizers import l2

# Download necessary NLTK resources
# nltk.download('punkt')
# nltk.download('wordnet')

# Initialize lemmatizer
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
# Define directories for each dataset
directories = [
    'agoda_hotel_reviews',  
    'tripadvisor_hotel_reviews',
    'klook_hotel_reviews',  
    'booking_hotel_reviews'
]

# %%
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Function to load and normalize data
def load_and_normalize_data(directories):
    hotel_dfs = {}
    
    for directory in directories:           
        path = os.path.join('../raw data', directory)
        
        for filename in os.listdir(path):
            if filename.endswith('.csv'):
                # Extract hotel name from filename by removing undesired part
                hotel_name = os.path.splitext(filename)[0].replace('_reviews_2022_2024', '')
                
                df = pd.read_csv(os.path.join(path, filename))
                
                # Normalize the Review Score
                scaler = MinMaxScaler(feature_range=(0, 1))
                df['normalized_score'] = scaler.fit_transform(df[['Review Score']])

                # Add a new column for hotel name
                df['Hotel'] = hotel_name
                
                # Concatenate to the hotel DataFrame
                if hotel_name in hotel_dfs:
                    hotel_dfs[hotel_name] = pd.concat([hotel_dfs[hotel_name], df], ignore_index=True)
                else:
                    hotel_dfs[hotel_name] = df.reset_index(drop=True)

    return hotel_dfs


# Load and normalize data
hotel_dfs = load_and_normalize_data(directories)

# %%
print(list(hotel_dfs))
# Out:
# ['bai_hotel', 'dusit_thani_mactan', 'fairfield_by_marriott_cebu', 'jpark_island_resort_and_waterpark', 'seda_ayala_center_cebu', 'waterfront_hotel_and_casino']

# %%
# Function to lemmatize text and check if it's in English
# for identifying english reviews
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException
def preprocess_text(text):
    try:
        # Check if the review is in English
        lang = detect(text)
        if lang != 'en':
            return None  # Return None if not in English

        # Step 1: Convert text to lowercase
        text = text.lower()

        # Step 2: Remove punctuation
        text = text.translate(str.maketrans('', '', string.punctuation))

        # Step 3: Tokenization
        tokens = nltk.word_tokenize(text)

        # Step 4: Remove stop words
        tokens = [word for word in tokens if word not in stop_words]

        # Step 5: Lemmatization
        lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens]

        # Return the processed text as a single string
        return ' '.join(lemmatized_tokens)

    except LangDetectException as e:
        # If language detection fails, return None
        print(f"error: {e}")
        return None

# Loop through each hotel DataFrame and preprocess the review content
for hotel, df in hotel_dfs.items():
    # Apply preprocessing to the DataFrame's 'Review Content' column
    df['cleaned_content'] = df['Review Content'].apply(preprocess_text)

    # Identify and print the removed reviews (non-English)
    removed_reviews = df[df['cleaned_content'].isnull()]['Review Content']
    print(f"Removed reviews from {hotel}:")
    print(removed_reviews)

    # Drop rows where 'cleaned_content' is None (non-English reviews)
    df = df.dropna(subset=['cleaned_content'])

    # Update the DataFrame in the dictionary
    hotel_dfs[hotel] = df

# Display the cleaned DataFrames for each hotel
for hotel_name, df in hotel_dfs.items():
    print(f"\nCleaned DataFrame for {hotel_name}:")
    print(df)
# Out:
# error: No features in text.
# Removed reviews from bai_hotel:
# 11                                    Excellent\r\n \r\n
# 31      Napakaganda ang mura pa dito ulit ako mag ssta...
# 43                                        Good \r\n \r\n
# 45                   No frills, reliable hotel.\r\n \r\n
# 47                            Great experience \r\n \r\n
#                               ...
# 3897                              \r\n nice room\r\n none
# 3905        \r\n friendly.   Amazzzzzinnng breakfast\r\n
# 3978    \r\n La gentillesse du personnel, la piscine, ...
# 4022                                       \r\n Good\r\n
# 4032                           \r\n \r\n slow internet. 😔
# Name: Review Content, Length: 168, dtype: object
# error: No features in text.
# error: No features in text.
# Removed reviews from dusit_thani_mactan:
# 6                                     Excellent\r\n \r\n
# 10                                        全てが最高\r\n \r\n
# 19                              beautiful hotel\r\n \r\n
# 25      Beautiful resort and staff are excellent servi...
# 42                    inside bed have sands\r\n\r\n \r\n
# 44                           WORTH THE PRICE!! \r\n \r\n
# 46                                    Had fun..\r\n \r\n
# 66                                    Excellent\r\n \r\n
# 80                        Staffs are so amazing\r\n \r\n
# 81                                   Fantastic \r\n \r\n
# 86                                         Nice\r\n \r\n
# 87                      위치는 조금 별로지만 나머지는 다 좋습니다\r\n \r\n
# 137                                           .\r\n \r\n
# 140                                   Very good\r\n \r\n
# 153                                        Nice\r\n \r\n
# 158     インフィニティプールはとても素敵でした。水温もちょうどよく、気持ちよかったです。ただお部屋の...
# 171                                  Nice place\r\n \r\n
# 179     장점 : 수영장이 이쁘다. 카운터 직원들이 친절함, 매일같이 식당가에 깨끗하게 청소...
# 180                               Amazing stay.\r\n \r\n
# 191                                     So good\r\n \r\n
# 192                               awesome hotel\r\n \r\n
# 204                                        Good\r\n \r\n
# 211                                        Good\r\n \r\n
# 271                                   Christine\r\n \r\n
# 279                           Superb experience\r\n \r\n
# 290                                       Best \r\n \r\n
# 320                                        good\r\n \r\n
# 321                                        good\r\n \r\n
# 326                                Very decent!\r\n \r\n
# 327                               Too expensive\r\n \r\n
# 349                                        Good\r\n \r\n
# 367                                Good!!!!!!!!\r\n \r\n
# 394                          Best hotel in cebu\r\n \r\n
# 422                            Don't use agoda \r\n \r\n
# 435                  Very relaxing environment!\r\n \r\n
# 448     We can say that our stay at Dusit is the best....
# 457                                Amazing stay\r\n \r\n
# 515                                        good\r\n \r\n
# 571                                     not bad\r\n \r\n
# 586                                           ,\r\n \r\n
# 702     Great food yummy fish and ships and friendly s...
# 879     This is the best hotel!\r\nとてもスタッフの皆さんが親切にしてくれ...
# 1390                     \r\n \r\n No tv channels working
# 1425                                       \r\n Pool\r\n
# 1447                            \r\n Amazing service\r\n
# 1453                                     \r\n good\r\n no
# 1548                            \r\n LOTS OF CHOICES\r\n
# 1644    \r\n nice ambiance,clean!!\r\n poor service at...
# 1654                               \r\n great place!\r\n
# 1739            \r\n Overall excellent Hotel\r\n Location
# 1769                                   \r\n beatiful\r\n
# 1792                              \r\n pool and view\r\n
# 1818                                    \r\n all\r\n none
# 1854                    \r\n Sea View\r\n No gym , no Spa
# Name: Review Content, dtype: object
# Removed reviews from fairfield_by_marriott_cebu:
# Series([], Name: Review Content, dtype: object)
# Removed reviews from jpark_island_resort_and_waterpark:
# 6                                          N/A\r\n \r\n
# 32                             Very nice place\r\n \r\n
# 37                          Avoid at all cost \r\n \r\n
# 57     고령에 첫번째 세부지역 자유여행인데도 아고다지원의 세심한 배려와 친절로 불편없이 즐...
# 66                                        None\r\n \r\n
# 67     세부에 총 5번 방문 했지만 역시 제이파크는 여전히 최고의 숙소라고 자부합니다. 다...
# 68                    말이 필요없습니다. 단연 최고의 호텔입니다.\r\n \r\n
# 78                                        Good\r\n \r\n
# 91                                 Good 👍 👍 👍 \r\n \r\n
# 93                           Such a nice place\r\n \r\n
# 107                                 Good  good\r\n \r\n
# 109                                   verygood\r\n \r\n
# 113                                  Very good\r\n \r\n
# 115                   Nice place for pleasure.\r\n \r\n
# 119                                          c\r\n \r\n
# 123                                   gooddddd\r\n \r\n
# 164                        Excellent service. \r\n \r\n
# 165                                 Very good \r\n \r\n
# 184                          Great experience!\r\n \r\n
# 214                                   superb!!\r\n \r\n
# 254    Nice place despite Odette. Excellent Service\r...
# 255                                Keep it up!\r\n \r\n
# 261                                       Nice\r\n \r\n
# 370                                      Giggity giggity
# 385                   \r\n Nice facilities\r\n Cleanness
# 404                         \r\n Waterpark for kids\r\n
# 409                              \r\n Overall sites\r\n
# 411         \r\n rooms, restaurants, water park\r\n none
# 516                                  \r\n Breskfast\r\n
# 539          \r\n all in one\r\n water slide not working
# 546                                \r\n Nice place.\r\n
# Name: Review Content, dtype: object
# error: No features in text.
# Removed reviews from seda_ayala_center_cebu:
# 6                                  GOOD\r\n \r\n
# 38                                 Nice\r\n \r\n
# 39      Full gym with sauna was amazing\r\n \r\n
# 40      Full gym with sauna was amazing\r\n \r\n
# 61                    Super convenient \r\n \r\n
#                           ...
# 1675                   \r\n 4 star amenities\r\n
# 1676                        \r\n Food\r\n Crowded
# 1786                          \r\n nice\r\n clean
# 1825         \r\n convenient\r\n not clean enough
# 1829                    \r\n Superb service.\r\n
# Name: Review Content, Length: 77, dtype: object
# error: No features in text.
# error: No features in text.
# error: No features in text.
# error: No features in text.
# error: No features in text.
# error: No features in text.
# error: No features in text.
# Removed reviews from waterfront_hotel_and_casino:
# 0                                  All good \r\n \r\n
# 1                                       okay\r\n \r\n
# 2                                   okay\r\n\r\n \r\n
# 3                                       okay\r\n \r\n
# 4                                       okay\r\n \r\n
#                              ...
# 1513                               \r\n none\r\n dirty
# 1534    \r\n Buffet breakfast and dinner\r\n No issues
# 1579             \r\n very good room attendant\r\n n/a
# 1597                                  \r\n Buffet\r\n
# 1664                              \r\n None\r\n Casino
# Name: Review Content, Length: 104, dtype: object
#
# Cleaned DataFrame for bai_hotel:
#      Review Provider  Review ID  \
# 0              Agoda  831639368
# 1              Agoda  830646554
# 2              Agoda  830862563
# 3              Agoda  830828036
# 4              Agoda  823596890
# ...              ...        ...
# 4034     Booking.com  493857566
# 4035     Booking.com  493857758
# 4036     Booking.com  493857673
# 4037     Booking.com  493857733
# 4038     Booking.com  475018064
#
#                                          Review Content  Review Score  \
# 0     The hotel's facilities were top notch, from th...           9.6
# 1     I enjoyed my stay at the Bai Hotel. The prices...          10.0
# 2                           My favorite hotel\r\n \r\n           10.0
# 3     This hotel was so accommodating. Good staff, g...          10.0
# 4                            Well recommended\r\n \r\n           10.0
# ...                                                 ...           ...
# 4034  \r\n It is very clean; the staff were very cou...           9.0
# 4035  \r\n The food is good, staff and friendly and ...          10.0
# 4036         \r\n its ok\r\n the food is very very cold           1.0
# 4037  \r\n From the moment we checked in, everything...          10.0
# 4038  \r\n Front desk staff verry helpful.\r\n Very ...           8.0
#
#                     Review Time  normalized_score      Hotel  \
# 0     2024-07-16T09:26:00+07:00          0.950000  bai_hotel
# 1     2024-07-15T12:05:00+07:00          1.000000  bai_hotel
# 2     2024-07-15T07:56:00+07:00          1.000000  bai_hotel
# 3     2024-07-15T04:07:00+07:00          1.000000  bai_hotel
# 4     2024-07-14T07:00:00+07:00          1.000000  bai_hotel
# ...                         ...               ...        ...
# 4034  2022-01-25T12:36:00+07:00          0.888889  bai_hotel
# 4035  2022-01-24T14:16:44+07:00          1.000000  bai_hotel
# 4036  2022-01-23T11:55:47+07:00          0.000000  bai_hotel
# 4037  2022-01-17T04:02:03+07:00          1.000000  bai_hotel
# 4038  2022-01-13T23:25:22+07:00          0.777778  bai_hotel
#
#                                         cleaned_content
# 0     hotel facility top notch well maintained ameni...
# 1     enjoyed stay bai hotel price reasonable room n...
# 2                                        favorite hotel
# 3     hotel accommodating good staff great ambiance ...
# 4                                      well recommended
# ...                                                 ...
# 4034  clean staff courteous polite booked double bed...
# 4035  food good staff friendly accommodation room co...
# 4036                                       ok food cold
# 4037  moment checked everything great decided extend...
# 4038  front desk staff verry helpful bad system chec...
#
# [3871 rows x 8 columns]
#
# Cleaned DataFrame for dusit_thani_mactan:
#      Review Provider  Review ID  \
# 0              Agoda  831818821
# 1              Agoda  831474199
# 2              Agoda  830695618
# 3              Agoda  830692306
# 4              Agoda  830498590
# ...              ...        ...
# 1883     Booking.com  475014596
# 1884     Booking.com  475014594
# 1885     Booking.com  475014600
# 1886     Booking.com  475014598
# 1887     Booking.com  473150513
#
#                                          Review Content  Review Score  \
# 0     They have Karaoke Night on Wednesdays and Satu...          10.0
# 1                 The rooms have so bad smell\r\n \r\n            5.2
# 2             A perfect place for a getaway. \r\n \r\n            9.2
# 3     Great experience from Dusit Thani, Mactan!\r\n...           9.6
# 4     it looks good in photos but there is nothing t...           2.8
# ...                                                 ...           ...
# 1883  \r\n Even though typoon oddette came the servi...          10.0
# 1884               \r\n clean rooms, infinity pool\r\n            8.0
# 1885  \r\n Their memory pillows. I bought myself a p...           6.0
# 1886  \r\n friendly Staffs and the property was very...           7.0
# 1887  \r\n Love that even when it was windy and rain...           9.0
#
#                     Review Time  normalized_score               Hotel  \
# 0     2024-07-16T12:18:00+07:00          1.000000  dusit_thani_mactan
# 1     2024-07-16T07:06:00+07:00          0.400000  dusit_thani_mactan
# 2     2024-07-15T10:48:00+07:00          0.900000  dusit_thani_mactan
# 3     2024-07-15T10:08:00+07:00          0.950000  dusit_thani_mactan
# 4     2024-07-13T04:33:00+07:00          0.100000  dusit_thani_mactan
# ...                         ...               ...                 ...
# 1883  2022-01-07T06:45:24+07:00          1.000000  dusit_thani_mactan
# 1884  2022-01-04T00:00:10+07:00          0.777778  dusit_thani_mactan
# 1885  2022-01-02T23:16:17+07:00          0.555556  dusit_thani_mactan
# 1886  2022-01-02T06:41:15+07:00          0.666667  dusit_thani_mactan
# 1887  2022-01-01T14:39:04+07:00          0.888889  dusit_thani_mactan
#
#                                         cleaned_content
# 0     karaoke night wednesday saturday restaurant po...
# 1                                        room bad smell
# 2                                 perfect place getaway
# 3                   great experience dusit thani mactan
# 4     look good photo nothing food selection worst also
# ...                                                 ...
# 1883  even though typoon oddette came service still ...
# 1884                           clean room infinity pool
# 1885  memory pillow bought pair checking wifi pool d...
# 1886                      friendly staff property clean
# 1887  love even windy raining staff kept nye celeb s...
#
# [1834 rows x 8 columns]
#
# Cleaned DataFrame for fairfield_by_marriott_cebu:
#     Review Provider  Review ID  \
# 0             Agoda  817554055
# 1             Agoda  816309595
# 2             Agoda  815995536
# 3             Agoda  791649125
# 4             Agoda  791504757
# ..              ...        ...
# 102     Booking.com  767544892
# 103     Booking.com  763104075
# 104     Booking.com  763104088
# 105     Booking.com  756197102
# 106     Booking.com  756197092
#
#                                         Review Content  Review Score  \
# 0    Overall, my experience was positive.  It is ma...           8.8
# 1    Marriott is always with pretty good interior d...          10.0
# 2    Beautiful new hotel with very attentive and pr...          10.0
# 3      The staff are superb. Nice experience\r\n \r\n            9.6
# 4    I had flown from Vancouver to Manila and then ...          10.0
# ..                                                 ...           ...
# 102  \r\n Perfect overnight at the Fairfield by Mar...          10.0
# 103  \r\n Staff friendly and helpful\r\nRoom clean ...          10.0
# 104  \r\n Clean and staff\r\n Countdown party can b...          10.0
# 105  \r\n I would like to have a call from your cus...          10.0
# 106                 \r\n The stuff and comfort\r\n N/a          10.0
#
#                    Review Time  normalized_score                       Hotel  \
# 0    2024-06-16T07:48:00+07:00               0.4  fairfield_by_marriott_cebu
# 1    2024-06-10T03:12:00+07:00               1.0  fairfield_by_marriott_cebu
# 2    2024-06-06T08:55:00+07:00               1.0  fairfield_by_marriott_cebu
# 3    2024-04-13T07:27:00+07:00               0.8  fairfield_by_marriott_cebu
# 4    2024-04-11T10:07:00+07:00               1.0  fairfield_by_marriott_cebu
# ..                         ...               ...                         ...
# 102  2024-01-17T03:45:11+07:00               1.0  fairfield_by_marriott_cebu
# 103  2024-01-07T09:09:46+07:00               1.0  fairfield_by_marriott_cebu
# 104  2024-01-02T07:42:09+07:00               1.0  fairfield_by_marriott_cebu
# 105  2023-12-21T19:55:14+07:00               1.0  fairfield_by_marriott_cebu
# 106  2023-12-21T07:00:00+07:00               1.0  fairfield_by_marriott_cebu
#
#                                        cleaned_content
# 0    overall experience positive marriot branding a...
# 1    marriott always pretty good interior design su...
# 2    beautiful new hotel attentive professional sta...
# 3                         staff superb nice experience
# 4    flown vancouver manila connecting flight cebu ...
# ..                                                 ...
# 102  perfect overnight fairfield marriot cebú 100 r...
# 103  staff friendly helpful room clean comfy bed gr...
# 104            clean staff countdown party done better
# 105  would like call customer service git extra cha...
# 106                                   stuff comfort na
#
# [107 rows x 8 columns]
#
# Cleaned DataFrame for jpark_island_resort_and_waterpark:
#     Review Provider  Review ID  \
# 0             Agoda  830298948
# 1             Agoda  830108653
# 2             Agoda  830092517
# 3             Agoda  829942341
# 4             Agoda  829881768
# ..              ...        ...
# 550     Booking.com  493769524
# 551     Booking.com  493769577
# 552     Booking.com  493769468
# 553     Booking.com  493769544
# 554     Booking.com  475016924
#
#                                         Review Content  Review Score  \
# 0    Room is disintegrating. Overpriced for the fac...           4.8
# 1    Very nice place especially when you are with f...          10.0
# 2    The place was great and had a lot of amenities...           8.8
# 3    The whole family had so much fun with the wate...          10.0
# 4    Wonderful food\r\nFun for family\r\nGreat acti...          10.0
# ..                                                 ...           ...
# 550  \r\n facilities. pools.  foods staff.\r\n balc...          10.0
# 551  \r\n Amenities.\r\n Fridge leaked. One of the ...           9.0
# 552  \r\n The comfort and cleanliness\r\n Slightly ...           9.0
# 553  \r\n Breakfast has many varieties and you can ...           9.0
# 554              \r\n nice suite room, pool, food\r\n            9.0
#
#                    Review Time  normalized_score  \
# 0    2024-07-10T11:47:00+07:00          0.480000
# 1    2024-07-08T07:07:00+07:00          1.000000
# 2    2024-07-08T03:10:00+07:00          0.880000
# 3    2024-07-06T07:46:00+07:00          1.000000
# 4    2024-07-05T10:21:00+07:00          1.000000
# ..                         ...               ...
# 550  2022-02-15T23:19:11+07:00          1.000000
# 551  2022-02-13T11:04:38+07:00          0.888889
# 552  2022-02-13T10:23:48+07:00          0.888889
# 553  2022-01-20T14:51:15+07:00          0.888889
# 554  2022-01-04T00:00:50+07:00          0.888889
#
#                                  Hotel  \
# 0    jpark_island_resort_and_waterpark
# 1    jpark_island_resort_and_waterpark
# 2    jpark_island_resort_and_waterpark
# 3    jpark_island_resort_and_waterpark
# 4    jpark_island_resort_and_waterpark
# ..                                 ...
# 550  jpark_island_resort_and_waterpark
# 551  jpark_island_resort_and_waterpark
# 552  jpark_island_resort_and_waterpark
# 553  jpark_island_resort_and_waterpark
# 554  jpark_island_resort_and_waterpark
#
#                                        cleaned_content
# 0    room disintegrating overpriced facility activi...
# 1                         nice place especially family
# 2    place great lot amenity cater age especially k...
# 3    whole family much fun waterparks slide breakfa...
# 4             wonderful food fun family great activity
# ..                                                 ...
# 550    facility pool food staff balcony door hard open
# 551          amenity fridge leaked one key card ’ work
# 552    comfort cleanliness slightly long check process
# 553  breakfast many variety choose want eat food de...
# 554                          nice suite room pool food
#
# [524 rows x 8 columns]
#
# Cleaned DataFrame for seda_ayala_center_cebu:
#      Review Provider  Review ID  \
# 0              Agoda  831739565
# 1              Agoda  830491273
# 2              Agoda  830421830
# 3              Agoda  830363373
# 4              Agoda  830265888
# ...              ...        ...
# 1961     Booking.com  493744542
# 1962     Booking.com  493744825
# 1963     Booking.com  493744560
# 1964     Booking.com  493744616
# 1965     Booking.com  473162020
#
#                                          Review Content  Review Score  \
# 0     Our stay us awesome i will definitely recommen...           8.4
# 1     If you’re looking for a hotel near the visa ce...           8.4
# 2     Hoping to receive discount in the future\r\n \...          10.0
# 3     Booked room for 2 guests. When we arrived, hot...           6.4
# 4                              Great location\r\n \r\n           10.0
# ...                                                 ...           ...
# 1961  \r\n the room was quite big, bed comfortable. ...           8.0
# 1962  \r\n I stayed at SEDA Ayala Center Cebu to do ...           9.0
# 1963  \r\n I liked the location, it was perfect cons...           5.0
# 1964  \r\n clean and good food\r\n customer service ...           7.0
# 1965          \r\n Big rooms, good service\r\n Nothing.           8.0
#
#                     Review Time  normalized_score                   Hotel  \
# 0     2024-07-16T10:58:00+07:00          0.800000  seda_ayala_center_cebu
# 1     2024-07-13T01:53:00+07:00          0.800000  seda_ayala_center_cebu
# 2     2024-07-12T04:13:00+07:00          1.000000  seda_ayala_center_cebu
# 3     2024-07-11T09:53:00+07:00          0.550000  seda_ayala_center_cebu
# 4     2024-07-10T04:25:00+07:00          1.000000  seda_ayala_center_cebu
# ...                         ...               ...                     ...
# 1961  2022-01-17T10:05:13+07:00          0.777778  seda_ayala_center_cebu
# 1962  2022-01-10T02:35:35+07:00          0.888889  seda_ayala_center_cebu
# 1963  2022-01-07T01:57:17+07:00          0.444444  seda_ayala_center_cebu
# 1964  2022-01-05T16:12:40+07:00          0.666667  seda_ayala_center_cebu
# 1965  2022-01-01T19:32:20+07:00          0.777778  seda_ayala_center_cebu
#
#                                         cleaned_content
# 0     stay u awesome definitely recommends thanks se...
# 1                      ’ looking hotel near visa center
# 2                        hoping receive discount future
# 3     booked room 2 guest arrived hotel claimed book...
# 4                                        great location
# ...                                                 ...
# 1961  room quite big bed comfortable catering staff ...
# 1962  stayed seda ayala center cebu mandatory hotel ...
# 1963  liked location perfect considering adjacent ay...
# 1964          clean good food customer service friendly
# 1965                      big room good service nothing
#
# [1889 rows x 8 columns]
#
# Cleaned DataFrame for waterfront_hotel_and_casino:
#      Review Provider  Review ID  \
# 5              Agoda  830831072
# 6              Agoda  830602728
# 7              Agoda  830514069
# 8              Agoda  830331658
# 9              Agoda  830205494
# ...              ...        ...
# 1682             NaN  493909284
# 1683             NaN  493909298
# 1684             NaN  493909242
# 1685             NaN  475015759
# 1686             NaN  475015758
#
#                                          Review Content  Review Score  \
# 5        Elevator too slow!! Need to improve \r\n \r\n            8.0
# 6     We stayed with my husband for a couple of days...           6.8
# 7     The air-conditioning in the room is not functi...           5.6
# 8     I had bug bites in my groin and legs  inspite ...           6.8
# 9                            Worst agoda apps\r\n \r\n            2.0
# ...                                                 ...           ...
# 1682  \r\n Kindness and great service\r\n Internet Poor           9.0
# 1683  \r\n It’s located at the heart of the city. Ve...           9.0
# 1684  \r\n It looks and smells clean from the lobby ...           5.0
# 1685  \r\n Room,Location ,pool,Breakfast\r\n Slow Wi...           8.0
# 1686  \r\n I have been going to the Waterfront for m...          10.0
#
#                     Review Time  normalized_score  \
# 5     2024-07-15T04:26:00+07:00          0.750000
# 6     2024-07-14T10:47:00+07:00          0.600000
# 7     2024-07-13T08:30:00+07:00          0.450000
# 8     2024-07-10T10:51:00+07:00          0.600000
# 9     2024-07-09T09:05:00+07:00          0.000000
# ...                         ...               ...
# 1682  2022-02-20T05:45:27+07:00          0.888889
# 1683  2022-01-21T06:18:20+07:00          0.888889
# 1684  2022-01-17T10:11:10+07:00          0.444444
# 1685  2022-01-13T02:15:58+07:00          0.777778
# 1686  2022-01-09T22:15:34+07:00          1.000000
#
#                             Hotel  \
# 5     waterfront_hotel_and_casino
# 6     waterfront_hotel_and_casino
# 7     waterfront_hotel_and_casino
# 8     waterfront_hotel_and_casino
# 9     waterfront_hotel_and_casino
# ...                           ...
# 1682  waterfront_hotel_and_casino
# 1683  waterfront_hotel_and_casino
# 1684  waterfront_hotel_and_casino
# 1685  waterfront_hotel_and_casino
# 1686  waterfront_hotel_and_casino
#
#                                         cleaned_content
# 5                            elevator slow need improve
# 6     stayed husband couple day staff nice lobby goo...
# 7     airconditioning room functioning properly sett...
# 8     bug bite groin leg inspite change per request ...
# 9                                      worst agoda apps
# ...                                                 ...
# 1682               kindness great service internet poor
# 1683  ’ located heart city accessible restaurant sti...
# 1684  look smell clean lobby room mountaincity view ...
# 1685  roomlocation poolbreakfast slow wifi cable was...
# 1686  going waterfront many year whilst visiting phi...
#
# [1583 rows x 8 columns]

# %%
# Train/Test Split and creation of labels
train_test_splits = {}
for hotel, df in hotel_dfs.items():
    df['label'] = df['normalized_score'].apply(lambda x: 0 if x <= 0.25 else (2 if x >= 0.75 else 1))

    # Perform 70-30 train-test split
    train_df, test_df = train_test_split(df, test_size=0.3, random_state=42)

    train_test_splits[hotel] = {
        'train': train_df,
        'test': test_df
    }

    print(f"\nTrain DataFrame for {hotel}:")
    print(train_df[['normalized_score', 'label']].describe())
    
    print(f"\nTest DataFrame for {hotel}:")
    print(test_df[['normalized_score', 'label']].describe())
# Out:
# Train DataFrame for bai_hotel:
#        normalized_score        label
# count       2709.000000  2709.000000
# mean           0.910397     1.878922
# std            0.178989     0.385428
# min            0.000000     0.000000
# 25%            0.888889     2.000000
# 50%            1.000000     2.000000
# 75%            1.000000     2.000000
# max            1.000000     2.000000
#
# Test DataFrame for bai_hotel:
#        normalized_score        label
# count       1162.000000  1162.000000
# mean           0.910972     1.887263
# std            0.173579     0.378391
# min            0.000000     0.000000
# 25%            0.888889     2.000000
# 50%            1.000000     2.000000
# 75%            1.000000     2.000000
# max            1.000000     2.000000
#
# Train DataFrame for dusit_thani_mactan:
#        normalized_score        label
# count       1283.000000  1283.000000
# mean           0.815549     1.685892
# std            0.259901     0.594052
# min            0.000000     0.000000
# 25%            0.750000     2.000000
# 50%            0.950000     2.000000
# 75%            1.000000     2.000000
# max            1.000000     2.000000
#
# Test DataFrame for dusit_thani_mactan:
#        normalized_score       label
# count        551.000000  551.000000
# mean           0.828282    1.722323
# std            0.256750    0.556802
# min            0.000000    0.000000
# 25%            0.750000    2.000000
# 50%            1.000000    2.000000
# 75%            1.000000    2.000000
# max            1.000000    2.000000
#
# Train DataFrame for fairfield_by_marriott_cebu:
#        normalized_score      label
# count          74.00000  74.000000
# mean            0.79527   1.675676
# std             0.28165   0.664318
# min             0.00000   0.000000
# 25%             0.75000   2.000000
# 50%             1.00000   2.000000
# 75%             1.00000   2.000000
# max             1.00000   2.000000
#
# Test DataFrame for fairfield_by_marriott_cebu:
#        normalized_score      label
# count         33.000000  33.000000
# mean           0.740909   1.606061
# std            0.318555   0.704423
# min            0.000000   0.000000
# 25%            0.500000   1.000000
# 50%            0.750000   2.000000
# 75%            1.000000   2.000000
# max            1.000000   2.000000
#
# Train DataFrame for jpark_island_resort_and_waterpark:
#        normalized_score       label
# count        366.000000  366.000000
# mean           0.821494    1.732240
# std            0.238498    0.548371
# min            0.000000    0.000000
# 25%            0.760000    2.000000
# 50%            0.888889    2.000000
# 75%            1.000000    2.000000
# max            1.000000    2.000000
#
# Test DataFrame for jpark_island_resort_and_waterpark:
#        normalized_score       label
# count        158.000000  158.000000
# mean           0.805767    1.677215
# std            0.239450    0.589386
# min            0.000000    0.000000
# 25%            0.720000    1.000000
# 50%            0.888889    2.000000
# 75%            1.000000    2.000000
# max            1.000000    2.000000
#
# Train DataFrame for seda_ayala_center_cebu:
#        normalized_score        label
# count       1322.000000  1322.000000
# mean           0.859795     1.813162
# std            0.194437     0.454476
# min            0.000000     0.000000
# 25%            0.777778     2.000000
# 50%            0.950000     2.000000
# 75%            1.000000     2.000000
# max            1.000000     2.000000
#
# Test DataFrame for seda_ayala_center_cebu:
#        normalized_score       label
# count        567.000000  567.000000
# mean           0.847069    1.777778
# std            0.205474    0.482924
# min            0.000000    0.000000
# 25%            0.750000    2.000000
# 50%            0.900000    2.000000
# 75%            1.000000    2.000000
# max            1.000000    2.000000
#
# Train DataFrame for waterfront_hotel_and_casino:
#        normalized_score        label
# count       1108.000000  1108.000000
# mean           0.771959     1.624549
# std            0.246447     0.574851
# min            0.000000     0.000000
# 25%            0.650000     1.000000
# 50%            0.850000     2.000000
# 75%            1.000000     2.000000
# max            1.000000     2.000000
#
# Test DataFrame for waterfront_hotel_and_casino:
#        normalized_score       label
# count        475.000000  475.000000
# mean           0.763567    1.608421
# std            0.267322    0.631732
# min            0.000000    0.000000
# 25%            0.650000    1.000000
# 50%            0.850000    2.000000
# 75%            1.000000    2.000000
# max            1.000000    2.000000

# %%
# Count the occurrences of each label
positive_count = 0
negative_count = 0
neutral_count = 0

for hotel, df in hotel_dfs.items():
    neutral_count += (df['label'] == 1).sum()
    negative_count += (df['label'] == 0).sum()
    positive_count += (df['label'] == 2).sum()

# Print the counts
print(f'Positive reviews: {positive_count}')
print(f'Negative reviews: {negative_count}')
print(f'Neutral reviews: {neutral_count}')
print(f"Total: {positive_count+negative_count+neutral_count}")
# Out:
# Positive reviews: 8017
# Negative reviews: 385
# Neutral reviews: 1406
# Total: 9808

# %%
from sklearn.utils import shuffle
# Initialize combined lists
combined_X_train = []
combined_y_train = []

raw_train_data = {}
raw_test_data = {}

for hotel_name, df in hotel_dfs.items():
    # Split the dataset into training and testing sets
    X_train_raw, X_test_raw, y_train, y_test = train_test_split(
        df['cleaned_content'], 
        df['label'], 
        test_size=0.3, 
        stratify=df['label'], 
        random_state=42
    )
    
    # Store raw train/test data
    raw_train_data[hotel_name] = (X_train_raw, y_train)
    raw_test_data[hotel_name] = (X_test_raw, y_test)

    # Add to combined lists
    combined_X_train.extend(X_train_raw)  # Use extend to flatten the list for strings
    combined_y_train.extend(y_train.tolist())  # Ensure y_train is a list to extend it
    
# Tokenization
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(combined_X_train)  # Fit tokenizer on combined training data

# Convert texts to sequences
X_train_sequences = tokenizer.texts_to_sequences(combined_X_train)
X_test_sequences = []

# Optionally convert test texts into sequences for padding later
for hotel_name, (test_data, _) in raw_test_data.items():
    sequences = tokenizer.texts_to_sequences(test_data)
    X_test_sequences.append(sequences)

# Pad sequences to ensure uniform input size
X_train_padded = pad_sequences(X_train_sequences, maxlen=100)

# Pad test sequences for each hotel
X_test_padded = []
for sequences in X_test_sequences:
    padded_sequences = pad_sequences(sequences, maxlen=100)
    X_test_padded.append(padded_sequences)
    
# Shuffle the padded training data and corresponding labels
X_train_padded, combined_y_train = shuffle(X_train_padded, combined_y_train, random_state=42)

# Store the processed data in a combined format if desired
train_data = (X_train_padded, np.array(combined_y_train))  # Now a tuple of padded data and labels


# Prepare test data dictionary if needed
test_data = {}
for i, hotel_name in enumerate(raw_test_data.keys()):
    test_data[hotel_name] = X_test_padded[i], raw_test_data[hotel_name][1]  # Corresponding labels

# %%
from sklearn.model_selection import KFold
# Model creation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
def kfold_validation(df, text_column, label_column, num_words=5000, maxlen=100, k=5, epochs=10, learning_rate=1e-4):
    # Prepare data
    X = df[text_column].values
    y = df[label_column].values

    # Tokenization
    tokenizer = Tokenizer(num_words=num_words)
    tokenizer.fit_on_texts(X)
    sequences = tokenizer.texts_to_sequences(X)
    padded_sequences = pad_sequences(sequences, maxlen=maxlen)

    # K-Fold Cross-Validation
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    
    accuracy_results = []
    val_accuracy_results = []

    for fold, (train_index, val_index) in enumerate(kf.split(padded_sequences)):
        print(f"Training Fold {fold + 1}/{k}")
        
        # Split data into training and validation sets
        X_train, X_val = padded_sequences[train_index], padded_sequences[val_index]
        y_train, y_val = y[train_index], y[val_index]

        # Create and compile the model
        model = Sequential([
            Embedding(input_dim=num_words, output_dim=128, input_length=maxlen),
            Conv1D(filters=64, kernel_size=5, activation='relu'),
            MaxPooling1D(pool_size=2),
            Bidirectional(LSTM(64, return_sequences=True)),
            Bidirectional(LSTM(64)),
            Dense(64, activation='relu', kernel_regularizer=l2(0.001)),  # Adding L2 regularization
            Dropout(0.5),
            Dense(3, activation='softmax')  # Assuming 3 classes for multi-class classification
        ])
        
        model.compile(optimizer=Adam(learning_rate=learning_rate), 
                      loss='sparse_categorical_crossentropy', 
                      metrics=['accuracy'])
        
        # Early Stopping
        early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

        X_train_padded, y_train = train_data
        # Model Training
        history = model.fit(
            X_train_padded, 
            y_train, 
            epochs=10, 
            batch_size=32, 
            validation_split=0.2, 
            callbacks=[early_stopping]
        )

        # Store accuracy results for each fold
        accuracy = history.history['accuracy']
        val_accuracy = history.history['val_accuracy']
        accuracy_results.append(accuracy)
        val_accuracy_results.append(val_accuracy)

    return accuracy_results, val_accuracy_results, tokenizer

# %%
import pandas as pd

# Create DataFrame from combined training data
train_df = pd.DataFrame({
    'cleaned_content': combined_X_train,
    'label': combined_y_train
})

# Call the kfold_validation function
accuracy_results, val_accuracy_results, tokenizer = kfold_validation(
    df=train_df,
    text_column='cleaned_content',
    label_column='label',
    num_words=5000,
    maxlen=100,
    k=5,
    epochs=20,
    learning_rate=1e-4
)

# Print results
print("Training Accuracies per Fold:", accuracy_results)
print("Validation Accuracies per Fold:", val_accuracy_results)
# Out:
# Training Fold 1/5
# c:\Users\Predator\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 24s 68ms/step - accuracy: 0.7786 - loss: 0.9023 - val_accuracy: 0.8157 - val_loss: 0.6317
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.8203 - loss: 0.6421 - val_accuracy: 0.8157 - val_loss: 0.6067
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.8239 - loss: 0.5930 - val_accuracy: 0.8376 - val_loss: 0.4914
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - accuracy: 0.8595 - loss: 0.4544 - val_accuracy: 0.8361 - val_loss: 0.4851
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.8773 - loss: 0.4004 - val_accuracy: 0.8332 - val_loss: 0.5087
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.9028 - loss: 0.3478 - val_accuracy: 0.8237 - val_loss: 0.5396
# Epoch 7/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.9123 - loss: 0.3102 - val_accuracy: 0.8310 - val_loss: 0.5734
# Training Fold 2/5
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 24s 80ms/step - accuracy: 0.7871 - loss: 0.8843 - val_accuracy: 0.8157 - val_loss: 0.6310
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - accuracy: 0.8163 - loss: 0.6517 - val_accuracy: 0.8157 - val_loss: 0.6162
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.8168 - loss: 0.6203 - val_accuracy: 0.8165 - val_loss: 0.5481
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 63ms/step - accuracy: 0.8372 - loss: 0.4948 - val_accuracy: 0.8398 - val_loss: 0.4785
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - accuracy: 0.8749 - loss: 0.4080 - val_accuracy: 0.8376 - val_loss: 0.4814
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.8927 - loss: 0.3490 - val_accuracy: 0.8398 - val_loss: 0.5024
# Epoch 7/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 66ms/step - accuracy: 0.9029 - loss: 0.3173 - val_accuracy: 0.8230 - val_loss: 0.5296
# Training Fold 3/5
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 22s 66ms/step - accuracy: 0.7774 - loss: 0.8923 - val_accuracy: 0.8157 - val_loss: 0.6393
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8250 - loss: 0.6391 - val_accuracy: 0.8157 - val_loss: 0.6117
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.8126 - loss: 0.6053 - val_accuracy: 0.8339 - val_loss: 0.4880
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.8535 - loss: 0.4529 - val_accuracy: 0.8405 - val_loss: 0.4812
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8864 - loss: 0.3744 - val_accuracy: 0.8398 - val_loss: 0.4887
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 9s 54ms/step - accuracy: 0.8946 - loss: 0.3578 - val_accuracy: 0.8361 - val_loss: 0.5274
# Epoch 7/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 64ms/step - accuracy: 0.9030 - loss: 0.3286 - val_accuracy: 0.8150 - val_loss: 0.5635
# Training Fold 4/5
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 23s 69ms/step - accuracy: 0.8004 - loss: 0.8661 - val_accuracy: 0.8157 - val_loss: 0.6391
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - accuracy: 0.8161 - loss: 0.6494 - val_accuracy: 0.8157 - val_loss: 0.6245
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.8250 - loss: 0.5924 - val_accuracy: 0.8369 - val_loss: 0.4966
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 74ms/step - accuracy: 0.8467 - loss: 0.4622 - val_accuracy: 0.8492 - val_loss: 0.4973
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - accuracy: 0.8762 - loss: 0.3909 - val_accuracy: 0.8383 - val_loss: 0.4991
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - accuracy: 0.8840 - loss: 0.3714 - val_accuracy: 0.8325 - val_loss: 0.5142
# Training Fold 5/5
# Epoch 1/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 25s 84ms/step - accuracy: 0.7501 - loss: 0.9352 - val_accuracy: 0.8157 - val_loss: 0.6362
# Epoch 2/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 78ms/step - accuracy: 0.8258 - loss: 0.6405 - val_accuracy: 0.8157 - val_loss: 0.6186
# Epoch 3/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - accuracy: 0.8142 - loss: 0.6275 - val_accuracy: 0.8165 - val_loss: 0.5406
# Epoch 4/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 12s 71ms/step - accuracy: 0.8302 - loss: 0.5157 - val_accuracy: 0.8288 - val_loss: 0.5395
# Epoch 5/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 13s 75ms/step - accuracy: 0.8713 - loss: 0.4190 - val_accuracy: 0.8274 - val_loss: 0.4971
# Epoch 6/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 12s 67ms/step - accuracy: 0.8837 - loss: 0.3728 - val_accuracy: 0.8157 - val_loss: 0.5293
# Epoch 7/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.9040 - loss: 0.3166 - val_accuracy: 0.8121 - val_loss: 0.5492
# Epoch 8/10
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 11s 65ms/step - accuracy: 0.9169 - loss: 0.2842 - val_accuracy: 0.8274 - val_loss: 0.5743
# Training Accuracies per Fold: [[0.8094370365142822, 0.8178174495697021, 0.826562225818634, 0.8611769080162048, 0.8788486123085022, 0.8967024683952332, 0.9125523567199707], [0.8098013997077942, 0.8178174495697021, 0.8185461759567261, 0.8394971489906311, 0.8677354454994202, 0.887957751750946, 0.901985764503479], [0.8085261583328247, 0.8172709345817566, 0.8223720192909241, 0.855893611907959, 0.8786664009094238, 0.8941519260406494, 0.9083621501922607], [0.81508469581604, 0.8176352977752686, 0.8212789297103882, 0.8560757637023926, 0.8744762539863586, 0.8901439309120178], [0.8001457452774048, 0.8172709345817566, 0.8200036287307739, 0.8460557460784912, 0.8704681992530823, 0.8890508413314819, 0.9008926749229431, 0.906175971031189]]
# Validation Accuracies per Fold: [[0.8157320022583008, 0.8157320022583008, 0.8375819325447083, 0.8361252546310425, 0.8332119584083557, 0.8237436413764954, 0.8310269713401794], [0.8157320022583008, 0.8157320022583008, 0.8164603114128113, 0.8397669196128845, 0.8375819325447083, 0.8397669196128845, 0.8230152726173401], [0.8157320022583008, 0.8157320022583008, 0.8339402675628662, 0.8404952883720398, 0.8397669196128845, 0.8361252546310425, 0.8150036334991455], [0.8157320022583008, 0.8157320022583008, 0.8368536233901978, 0.8492352366447449, 0.8383102416992188, 0.8324835896492004], [0.8157320022583008, 0.8157320022583008, 0.8164603114128113, 0.8288419246673584, 0.8273853063583374, 0.8157320022583008, 0.8120903372764587, 0.8273853063583374]]

# %%
import numpy as np

# Assuming accuracy_results and val_accuracy_results are lists of results from K-Fold
average_accuracy = np.mean([np.mean(acc) for acc in accuracy_results])
average_val_accuracy = np.mean([np.mean(val_acc) for val_acc in val_accuracy_results])

print(f'Average Training Accuracy: {average_accuracy:.4f}')
print(f'Average Validation Accuracy: {average_val_accuracy:.4f}')
import matplotlib.pyplot as plt

for fold in range(len(accuracy_results)):
    plt.plot(accuracy_results[fold], label=f'Fold {fold + 1}')

plt.title('Training Accuracy Across Folds')
plt.xlabel('Epochs')
plt.ylabel('Training Accuracy')
plt.legend()
plt.show()

for fold in range(len(val_accuracy_results)):
    plt.plot(val_accuracy_results[fold], label=f'Fold {fold + 1}')

plt.title('Validation Accuracy Across Folds')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.show()
# Out:
# Average Training Accuracy: 0.8527
# Average Validation Accuracy: 0.8268
